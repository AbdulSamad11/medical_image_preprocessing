# %%
from __future__ import print_function

import os
import numpy as np
import nibabel as nib
from scipy.signal import medfilt
from multiprocessing import Pool, cpu_count

# %%
def create_dir(path):
    if not os.path.isdir(path):
        os.makedirs(path)


def load_nii(path):
    nii = nib.load(path)
    return nii.get_data(), nii.get_affine()


def save_nii(data, path, affine):
    nib.save(nib.Nifti1Image(data, affine), path)
    return


def denoise(volume, kernel_size=3):
    return medfilt(volume, kernel_size)


def rescale_intensity(volume, percentils=[0.5, 99.5], bins_num=256):
    obj_volume = volume[np.where(volume > 0)]
    min_value = np.percentile(obj_volume, percentils[0])
    max_value = np.percentile(obj_volume, percentils[1])

    if bins_num == 0:
        obj_volume = (obj_volume - min_value) / (max_value - min_value).astype(np.float32)
    else:
        obj_volume = np.round((obj_volume - min_value) / (max_value - min_value) * (bins_num - 1))
        obj_volume[np.where(obj_volume < 1)] = 1
        obj_volume[np.where(obj_volume > (bins_num - 1))] = bins_num - 1

    volume = volume.astype(obj_volume.dtype)
    volume[np.where(volume > 0)] = obj_volume

    return volume


def equalize_hist(volume, bins_num=256):
    obj_volume = volume[np.where(volume > 0)]
    hist, bins = np.histogram(obj_volume, bins_num, normed=True)
    cdf = hist.cumsum()
    cdf = (bins_num - 1) * cdf / cdf[-1]

    obj_volume = np.round(np.interp(obj_volume, bins[:-1], cdf)).astype(obj_volume.dtype)
    volume[np.where(volume > 0)] = obj_volume
    return volume


def unwarp_enhance(arg, **kwarg):
    return enhance(*arg, **kwarg)


def enhance(src_path, dst_path, kernel_size=3,
            percentils=[0.5, 99.5], bins_num=256, eh=True):
    print("Preprocess on: ", src_path)
    try:
        volume, affine = load_nii(src_path)
        volume = denoise(volume, kernel_size)
        volume = rescale_intensity(volume, percentils, bins_num)
        if eh:
            volume = equalize_hist(volume, bins_num)
        save_nii(volume, dst_path, affine)
    except RuntimeError:
        print("\tFailed on: ", src_path)

# %%
parent_dir = os.path.dirname(os.getcwd())
data_dir = os.path.join(parent_dir, "final_fyp_prep/data")
data_src_dir = os.path.join(data_dir, "2-Brain")
data_dst_dir = os.path.join(data_dir, "4-Enhance")
data_labels = ["healthy", "pd"]
create_dir(data_dst_dir)

# %%
data_src_paths, data_dst_paths = [], []
for label in data_labels:
    src_label_dir = os.path.join(data_src_dir, label)
    dst_label_dir = os.path.join(data_dst_dir, label)
    create_dir(dst_label_dir)
    for subject in os.listdir(src_label_dir):
        data_src_paths.append(os.path.join(src_label_dir, subject))
        data_dst_paths.append(os.path.join(dst_label_dir, subject))

# %%
kernel_size = 3
percentils = [0.5, 99.5]
bins_num = 256
eh = True

# %%
# Test
# enhance(data_src_paths[0], data_dst_paths[0],
#         kernel_size, percentils, bins_num, eh)

# Multi-processing
subj_num = len(data_src_paths)
paras = zip(data_src_paths, data_dst_paths,
            [kernel_size] * subj_num,
            [percentils] * subj_num,
            [bins_num] * subj_num,
            [eh] * subj_num)
pool = Pool(processes=cpu_count())
pool.map(unwarp_enhance, paras)
# Out:
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/healthy/PPMI_103183_MR_3D_T2_FLAIR__br_raw_20211001010943238_92_S1068406_I1498877.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_100005_MR_3D_T2_FLAIR__br_raw_20220224203326919_154_S1108072_I1548624.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/healthy/PPMI_130190_MR_3D_T2_FLAIR__br_raw_20220225014525621_15_S1108182_I1548734.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_102321_MR_3D_T2_FLAIR__br_raw_20211214130707070_191_S1090364_I1526455.nii.gz
# <ipython-input-2-629f06e365a1>:8: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   return nii.get_data(), nii.get_affine()
# <ipython-input-2-629f06e365a1>:8: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   return nii.get_data(), nii.get_affine()
# <ipython-input-2-629f06e365a1>:8: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   return nii.get_data(), nii.get_affine()
# <ipython-input-2-629f06e365a1>:8: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   return nii.get_data(), nii.get_affine()
# <ipython-input-2-629f06e365a1>:8: DeprecationWarning: get_affine method is deprecated.
# Please use the ``img.affine`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
#   return nii.get_data(), nii.get_affine()
# <ipython-input-2-629f06e365a1>:8: DeprecationWarning: get_affine method is deprecated.
# Please use the ``img.affine`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
#   return nii.get_data(), nii.get_affine()
# <ipython-input-2-629f06e365a1>:8: DeprecationWarning: get_affine method is deprecated.
# Please use the ``img.affine`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
#   return nii.get_data(), nii.get_affine()
# <ipython-input-2-629f06e365a1>:8: DeprecationWarning: get_affine method is deprecated.
# Please use the ``img.affine`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
#   return nii.get_data(), nii.get_affine()
# <ipython-input-2-629f06e365a1>:40: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.
#   hist, bins = np.histogram(obj_volume, bins_num, normed=True)
# <ipython-input-2-629f06e365a1>:40: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.
#   hist, bins = np.histogram(obj_volume, bins_num, normed=True)
# <ipython-input-2-629f06e365a1>:40: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.
#   hist, bins = np.histogram(obj_volume, bins_num, normed=True)
# <ipython-input-2-629f06e365a1>:40: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.
#   hist, bins = np.histogram(obj_volume, bins_num, normed=True)
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/healthy/PPMI_101195_MR_3D_T2_FLAIR__br_raw_20210924164712654_79_S1066287_I1496369.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_101742_MR_3D_T2_FLAIR__br_raw_20210914010302108_161_S1062111_I1491290.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/healthy/PPMI_106127_MR_3D_T2_SAG_FLAIR__br_raw_20211124065644926_22_S1084533_I1519067.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_101384_MR_3D_T2_FLAIR_SAGITAL__br_raw_20220105145950228_100_S1093335_I1530287.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/healthy/PPMI_102447_MR_3D_T2_FLAIR__br_raw_20211001001431608_140_S1068380_I1498851.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/healthy/PPMI_106127_MR_3D_T2_SAG_FLAIR_ND_br_raw_20211124065639325_19_S1084532_I1519066.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_101124_MR_3D_T2_FLAIR__br_raw_20210916215701966_1_S1063531_I1493058.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_100842_MR_3D_T2_FLAIR__br_raw_20210913210431934_32_S1062042_I1491221.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/healthy/PPMI_103183_MR_3D_T2_FLAIR_ND_br_raw_20211001010943636_69_S1068405_I1498876.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/healthy/PPMI_103467_MR_3D_T2_FLAIR__br_raw_20211124044046498_149_S1084505_I1519039.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_102479_MR_3D_T2_FLAIR__br_raw_20211124000148087_19_S1084440_I1518972.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_101048_MR_3D_T2_SAG_FLAIR_ND_br_raw_20210923220429888_67_S1065852_I1495868.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/healthy/PPMI_103161_MR_3D_T2_FLAIR__br_raw_20211124035700596_16_S1084493_I1519027.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/healthy/PPMI_100890_MR_3D_T2_FLAIR__br_raw_20210916214025837_1_S1063523_I1493050.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_100005_MR_3D_T2_FLAIR__br_raw_20211214115444977_107_S1090276_I1526361.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_102978_MR_3D_T2_FLAIR__br_raw_20211001002255813_98_S1068395_I1498866.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_101744_MR_3D_Brain_VIEW_FLAIR_SAG__br_raw_20210924181906384_53_S1066398_I1496490.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/healthy/PPMI_101039_MR_3D_T2_FLAIR_SAG_INVICCRO_T2_FLAIR__br_raw_20210924154947435_174_S1066205_I1496281.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/healthy/PPMI_101747_MR_3D_T2_SAG_FLAIR__br_raw_20210923225355002_52_S1065882_I1495898.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_40744_MR_3D_T2__SPC_FLAIR_C9C1HN007_br_raw_20220223200822238_40_S1107830_I1548286.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_101841_MR_3D_T2_FLAIR__br_raw_20211123225952455_59_S1084427_I1518959.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/healthy/PPMI_113369_MR_3D_T2_FLAIR__br_raw_20211210111310788_1_S1084568_I1519104.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/healthy/PPMI_113050_MR_3D_T2_FLAIR_ti1650_ND__br_raw_20220106132935142_90_S1093557_I1530530.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_101025_MR_3D_T2_FLAIR_SAGITAL__br_raw_20210930182706985_139_S1068226_I1498690.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_41356_MR_3D_T2_FLAIR__br_raw_20210929234653764_161_S1067874_I1498265.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/healthy/PPMI_115698_MR_SAG_3D_FLAIR_br_raw_20220105112301638_107_S1093264_I1530205.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_102475_MR_3D_T2_FLAIR__br_raw_20220105164302392_133_S1093347_I1530299.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_133507_MR_3D_T2_FLAIR_ti1650_ND__br_raw_20220225112608955_179_S1108303_I1548885.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_42415_MR_3D_T2_FLAIR_SAGITAL__br_raw_20220126052513255_84_S1099381_I1537671.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_110212_MR_3D_T2_FLAIR__br_raw_20211124075826857_108_S1084543_I1519077.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_58671_MR_3D_T2_SAG_FLAIR__br_raw_20210912031006630_79_S1061464_I1490573.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_101279_MR_3D_T2_FLAIR_SAGITAL__br_raw_20210930204511137_143_S1068301_I1498771.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_100017_MR_3D_T2_SAG_FLAIR__br_raw_20210726140817474_83_S1047946_I1473692.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_56744_MR_3D_T2_SAG_FLAIR_ND_br_raw_20210911100445751_44_S1061265_I1490374.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_101146_MR_3D_T2_FLAIR__br_raw_20211213113626238_71_S1089829_I1525835.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_42438_MR_3D_T2_FLAIR_SAGITAL__br_raw_20211213123557178_187_S1089944_I1525959.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_110535_MR_3D_T2_FLAIR__br_raw_20211211232636413_1_S1089590_I1525557.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_58783_MR_3D_T2_SAG_FLAIR__br_raw_20210912035115653_49_S1061478_I1490587.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/healthy/PPMI_102366_MR_3D_T2_FLAIR__br_raw_20210929001742262_38_S1067385_I1497686.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_101492_MR_3D_T2_FLAIR__br_raw_20210916224950499_1_S1063554_I1493081.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_3007_MR_Ax_3D_SWAN_GRE_straight__br_raw_20201229110220982_3_S989161_I1393671.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_105711_MR_Sag_3D_T2_FLAIR__br_raw_20211124053334085_5_S1084508_I1519042.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/healthy/PPMI_108909_MR_SAG_3D_FLAIR_br_raw_20211209123316065_105_S1088448_I1524137.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_101513_MR_3D_T2_SAG_FLAIR_ND_br_raw_20210923222918322_69_S1065867_I1495883.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_56435_MR_3D_T2_SAG_FLAIR_ND_br_raw_20210912002707723_132_S1061401_I1490510.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_102012_MR_3D_T2_FLAIR__br_raw_20210914014720200_135_S1062123_I1491302.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_112721_MR_3D_FLAIR_SPACE_br_raw_20220223170526099_51_S1107691_I1548081.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_102420_MR_3D_T2_FLAIR__br_raw_20210930235628648_49_S1068375_I1498846.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_101330_MR_3D_T2_FLAIR__br_raw_20210924172201324_177_S1066361_I1496453.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_100018_MR_3D_T2_FLAIR__br_raw_20210928204001552_13_S1067286_I1497587.nii.gz
# Preprocess on:  /home/abdul/Desktop/final_fyp_prep/data/2-Brain/pd/PPMI_109451_MR_3D_T2_FLAIR_SAGITAL__br_raw_20220105172023065_179_S1093362_I1530314.nii.gz
